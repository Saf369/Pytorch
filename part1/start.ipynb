# %%
import torch
print(torch.__version__)
# Out:
# 2.10.0+cu128

# %%
import torch
if torch.cuda.is_available():
    print("Gpu is available")
    print(f"using Gpu:{torch.cuda.get_device_name(0)}")
else:
    print("Gpu not available")
# Out:
# /home/saf369/Projects/pytorch/venv/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:283: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# Gpu not available

# %%
a=torch.empty(2,3)
type(a)
torch.zeros(2,3)
# Out:
# tensor([[0., 0., 0.],
#         [0., 0., 0.]])

# %%
def dy_dx(x):
    return 2*x
dy_dx(3)
# Out:
# 6

# %%
import math
def dz_dx(x):
    return 2 * x*math.cos(x**2)
dz_dx(2)
# Out:
# -2.6145744834544478

# %%
import torch
x=torch.tensor([1.0,2.0,3.0],requires_grad=True)
y=x*2
y.sum().backward()
print(x.grad)
# Out:
# /home/saf369/Projects/pytorch/venv/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:283: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# tensor([2., 2., 2.])

# %%
import numpy as np
import pandas as pd
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.datasets import load_breast_cancer


df=pd.read_csv("breast-cancer.csv")
df.head()
# df.shape
# Out:
#      age mefalsepause tumor-size inv-falsedes falsede-caps  deg-malig breast  \
# 0  40-49   premefalse      15-19          0-2         True          3  right
# 1  50-59         ge40      15-19          0-2        False          1  right
# 2  50-59         ge40      35-39          0-2        False          2   left
# 3  40-49   premefalse      35-39          0-2         True          3  right
# 4  40-49   premefalse      30-34          3-5         True          2   left
#
#   breast-quad  irradiat                    class
# 0     left_up     False        recurrence-events
# 1     central     False  false-recurrence-events
# 2    left_low     False        recurrence-events
# 3    left_low      True  false-recurrence-events
# 4    right_up     False        recurrence-events

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df.iloc[:, 1:],   # features
    df.iloc[:, 0],    # labels
    test_size=0.2,
    random_state=42
)

# %%
scaler=StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_test=scaler.transform(X_test)
type(X_train)
# <class 'scipy.sparse._csr.csr_matrix'>

X = df.drop("class", axis=1)
y = df["class"]
num_cols = ["deg-malig"]
bool_cols = ["irradiat"]
cat_cols = [
    "mefalsepause",
    "tumor-size",
    "inv-falsedes",
    "falsede-caps",
    "breast",
    "breast-quad"
]
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), num_cols),
        ("bool", "passthrough", bool_cols),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_cols),
    ]
)


from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=y_encoded
)

X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

X_train
# print(X)
y_train
print(y)
# Out:
# 0            recurrence-events
# 1      false-recurrence-events
# 2            recurrence-events
# 3      false-recurrence-events
# 4            recurrence-events
#                 ...
# 267    false-recurrence-events
# 268    false-recurrence-events
# 269    false-recurrence-events
# 270    false-recurrence-events
# 271    false-recurrence-events
# Name: class, Length: 272, dtype: str

# %%
y.value_counts()
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_train = le.fit_transform(y_train)
y_test=le.transform(y_test)

le.classes_


y_binary = (y_encoded == 0).astype(int)

y_binary = (y_encoded >= 2).astype(int)

mask = (y_encoded == 0) | (y_encoded == 1)
X_binary = X[mask]
y_binary = y_encoded[mask]


print(y)
# Out:
# 0            recurrence-events
# 1      false-recurrence-events
# 2            recurrence-events
# 3      false-recurrence-events
# 4            recurrence-events
#                 ...
# 267    false-recurrence-events
# 268    false-recurrence-events
# 269    false-recurrence-events
# 270    false-recurrence-events
# 271    false-recurrence-events
# Name: class, Length: 272, dtype: str

# %%
X_train_tensor = torch.from_numpy(X_train.toarray()).float()
X_test_tensor  = torch.from_numpy(X_test.toarray()).float()

y_train_tensor = torch.from_numpy(y_train).long()
y_test_tensor  = torch.from_numpy(y_test).long()

# %%
class MySimpleModel():
    def __init__(self):
        super().__init__()
        self.weight = torch.rand(shape=[1],dtype=torch.float64, requires_grad=True)
        self.bias=torch.zeros(1,dtype=torch.float64,requires_grad=True)

# %%
lr=0.1
epochs=25
